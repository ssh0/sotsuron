# %% [markdown]
# # 効率とシステムサイズの関係に関する確率モデルによる考察

# %% [markdown]
# ### 早稲田大学先進理工学部物理学科 山崎研究室 藤本將太郎

# %% [markdown]
# ## 1. 導入

# %% [markdown]
# 私達は普段の身近な生活の中で、考えているシステムの大きさが変わると、その中の質が変わったように感じる場面があるかもしれない。例えば教育の分野などではグループ学習の有効性が議論されることも多い。これはいくらかの賛同を得られることと思うが、こういったグループ学習も、そのグループの人数によって活動に参加しなくなる人が出てきたり、話がうまくまとまらなくなったりして、それより少ない人数でグループを組んだほうが良いのではないかと思うことがあるだろう。また、もう少し規模の大きいものでは、
